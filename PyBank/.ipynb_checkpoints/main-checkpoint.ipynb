# %%
from pathlib import Path
import csv
import datetime

Path.cwd()
# Out:
# WindowsPath('C:/Users/Jacob Grant Trading/OneDrive/Desktop/Classwork repo/python-homework/PyBank')

# %%
pybankpath = Path('C:/Users/jacob/OneDrive/Desktop/fintech_repo/02-Homework/02-Python/Instructions/PyBank/Resources/budget_data.csv')

# %%
pybank_records = []
pybank_months = []
dict_of_month_profit = {}
net_differences= []
max_increase = {}
max_decrease = {}

# %%
month_count = 0

# %%
total_profit_count = 0
avg_profit_change = 0
greatest_increase = 0
greatest_decrease = 0
change = 0

# %%
profit_change = 0

# %%
with open(pybankpath, 'r') as pybankfile:
    pybankreader = csv.reader(pybankfile, delimiter=',')
    header = next(pybankreader)
    
    
    for row in pybankreader:
        profit = int(row[1])
        pybank_records.append(profit)
    
   
    print(pybank_records)
# Out:
# [867884, 984655, 322013, -69417, 310503, 522857, 1033096, 604885, -216386, 477532, 893810, -80353, 779806, -335203, 697845, 793163, 485070, 584122, 62729, 668179, 899906, 834719, 132003, 309978, -755566, 1170593, 252788, 1151518, 817256, 570757, 506702, -1022534, 475062, 779976, 144175, 542494, 359333, 321469, 67780, 471435, 565603, 872480, 789480, 999942, -1196225, 268997, -687986, 1150461, 682458, 617856, 824098, 581943, 132864, 448062, 689161, 800701, 1166643, 947333, 578668, 988505, 1139715, 1029471, 687533, -524626, 158620, 87795, 423389, 840723, 568529, 332067, 989499, 778237, 650000, -1100387, -174946, 757143, 445709, 712961, -1163797, 569899, 768450, 102685, 795914, 60988, 138230, 671099]

# %%
for profits in pybank_records:
    month_count += 1
    total_profit_count += profits

    if month_count > 1:
        change = pybank_records[-1] - pybank_records[-2]
        net_differences.append(change)


    print(f'This is month #{month_count}, the profit the month is ${profits}, the change in profit is ${change}, & the total profit for this period is ${total_profit_count}')
    print(net_differences)
# Out:
# This is month #1, the profit the month is $867884, the change in profit is $0, & the total profit for this period is $867884
# []
# This is month #2, the profit the month is $984655, the change in profit is $532869, & the total profit for this period is $1852539
# [532869]
# This is month #3, the profit the month is $322013, the change in profit is $532869, & the total profit for this period is $2174552
# [532869, 532869]
# This is month #4, the profit the month is $-69417, the change in profit is $532869, & the total profit for this period is $2105135
# [532869, 532869, 532869]
# This is month #5, the profit the month is $310503, the change in profit is $532869, & the total profit for this period is $2415638
# [532869, 532869, 532869, 532869]
# This is month #6, the profit the month is $522857, the change in profit is $532869, & the total profit for this period is $2938495
# [532869, 532869, 532869, 532869, 532869]
# ...
